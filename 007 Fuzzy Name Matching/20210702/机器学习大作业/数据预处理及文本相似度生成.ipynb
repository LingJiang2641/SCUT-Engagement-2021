# %%
#Fuzzy Name Matching

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 
#实现多输出
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab  
import matplotlib.pyplot as plt  
import textdistance
import random

# %%
data = pd.read_excel('NameMatchingTrainingData.xlsx')
data.head()
# Out:
#                                   PRIMARY_NAME  \
# 0              GAZPROMBANK UPRAVLENIE AKTIVAMI
# 1              GAZPROMBANK UPRAVLENIE AKTIVAMI
# 2  UNITED INSTRUMENT MANUFACTURING CORPORATION
# 3                                 GAZ-OIL, OOO
# 4                                 Mr. Ken Wong
#
#                                             ALT_NAME  State
# 0                   GAZPROMBANK ASSET MANAGEMENT ZAO  Match
# 1  CLOSED JOINT-STOCK COMPANY GAZPROMBANK-UPRAVLE...  Match
# 2    JSC-UNITED-INSTRUMENT-MANUFACTURING-CORPORATION  Match
# 3                                            GAZ-OIL  Match
# 4                                       KEN WONG KAW  Match

# %%
def clean_data(name):
    data[name] = data[name].str.lower()
    data[name] =data[name].str.replace('mr.','')
    data[name] =data[name].str.replace('mrs.','')
    data[name] =data[name].str.replace('\n',' \n')
    data[name] =data[name].str.replace('\n',' \n')
    data[name] =data[name].str.replace('\n',' \n')
    data[name] =data[name].str.replace('.',' ')
    data[name] =data[name].str.replace(',',' ')
    data[name] =data[name].str.replace('\'','')
    data[name] =data[name].str.replace(' & ',' and ')
    data[name] =data[name].str.replace(' &',' and ')
    data[name] =data[name].str.replace('& ',' and ')
    data[name] =data[name].str.replace('&',' and ')
    data[name] =data[name].str.replace(' l p ',' lp ')
    data[name] =data[name].str.replace('l l p ','llp ')
    data[name] =data[name].str.replace('l l c ','llc ')
    data[name] =data[name].str.replace(' ltd ',' limited ')
    data[name] =data[name].str.replace(' p l c ',' plc')
    data[name] =data[name].str.replace(' co ltd ',' company limited ')
    data[name] =data[name].str.replace(' co ',' company ')
    data[name] =data[name].str.replace(' corp ',' corporation ')
    data[name] =data[name].str.replace(' univ ',' university ')
    data[name] =data[name].str.replace(' fdtn ',' foundation ')
    data[name] =data[name].str.replace(' inc ',' incorporated ')
    data[name] =data[name].str.replace(' assoc ',' association ')
    data[name] =data[name].str.replace(' mgmt ',' management ')
    data[name] =data[name].str.replace(' svsc ',' services ')
    data[name] =data[name].str.replace(' ag ',' aktiengesellschaft ')
    data[name] =data[name].str.replace(' govt ',' goverment ')
    data[name] =data[name].str.replace(' svgs ',' savings ')
    data[name] =data[name].str.replace(' intl ',' international ')
    data[name] =data[name].str.replace('intl ','international ')
    data[name] =data[name].str.replace(' investmentco lt ',' investment company limited ')
    data[name] = data[name].str.replace('the ','')
    data[name] = data[name].str.replace(' the ','')
    data[name] = data[name].str.strip()
clean_data('PRIMARY_NAME')
clean_data('ALT_NAME')

# %%
data
# Out:
#                                       PRIMARY_NAME  \
# 0                  gazprombank upravlenie aktivami
# 1                  gazprombank upravlenie aktivami
# 2      united instrument manufacturing corporation
# 3                                     gaz-oil  ooo
# 4                                         ken wong
# ...                                            ...
# 36864                              mondelez global
# 36865                       verizon communications
# 36866                  central and south west corp
# 36867                                bw consulting
# 36868                                temple-inland
#
#                                                 ALT_NAME      State
# 0                       gazprombank asset management zao      Match
# 1      closed joint-stock company gazprombank-upravle...      Match
# 2        jsc-united-instrument-manufacturing-corporation      Match
# 3                                                gaz-oil      Match
# 4                                           ken wong kaw      Match
# ...                                                  ...        ...
# 36864                           valanzano and associates  Not Match
# 36865                                    horry county sc  Not Match
# 36866                       sony bmg music entertainment  Not Match
# 36867                  salvation army - eastern division  Not Match
# 36868            colonial life and accident insurance co  Not Match
#
# [36869 rows x 3 columns]

# %%
def InStringSerch(a,b):
    return int(a in b or b in a)

# %%
data['Cosine Similarity'] = [textdistance.cosine.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Levenshtein Distance'] = [textdistance.levenshtein.distance(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Jaro-Winkler Distance'] = [textdistance.jaro_winkler.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Jaccard Index'] = [textdistance.jaccard.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Monge Elkan'] = [textdistance.monge_elkan.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['MRA'] = [textdistance.mra.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Longest Common Substring'] = [textdistance.lcsstr.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['Longest Common Subsequence'] = [textdistance.lcsseq.similarity(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]
data['In String Search'] = [InStringSerch(str(data.iloc[i]['PRIMARY_NAME']),str(data.iloc[i]['ALT_NAME'])) for i in range(len(data))]

# %%
writer = pd.ExcelWriter('data.xlsx')
data.to_excel(writer)
writer.save()
